# %%
import pickle
import pyrebase
import cv2
import os

import shutil
from Main_file import *

config = {
  "apiKey": "AIzaSyDtA3QrK4WXUGjCyzgXi_6vm7wJypXwy7U",
  "authDomain": "sbihackathon-cb717.firebaseapp.com",
  "databaseURL": "https://sbihackathon-cb717.firebaseio.com",
  "storageBucket": "sbihackathon-cb717.appspot.com",
  "serviceAccount": "./sbi_firestore.json"
}

firebase = pyrebase.initialize_app(config)


def add_to_firebase(identity, timestamp, face):
    db = firebase.database()
    storage = firebase.storage()
    current_pending_requests = db.child("notifications").shallow().get()
    if identity not in current_pending_requests.val():
        cv2.imwrite('notification_images/' + identity + '.jpeg', face)
        data = {'timestamp': timestamp}
        db.child("notifications").child(identity).set(data)
        storage.child("notifications/"+identity+".jpeg").put('notification_images/' + identity + '.jpeg')
        os.remove('notification_images/' + identity + '.jpeg')


def get_pickle_from_firebase():
    storage = firebase.storage()
    storage.child("database_backup/database.pkl").download('people/database.pkl')

def check_for_new():
    try:
        db = firebase.database()
        users = db.child("new_users").shallow().get()
        if users.val() is None:
            print("here")
            return False, None
        print("there")
        return bool(users), users
    except:
        return False, None


def upload_image(model, key):
    detector = FaceDetector()
    name = key
    images = [image for image in os.listdir('new_images/'+key)]
    vecs = []
    database = None
    for image in images:
        img = cv2.imread('new_images/' + key + '/' + image, 1)
        faces_cord = detector.detect(img)
        print("image aaya")
        if len(faces_cord):
            print("face aaya")
            faces = normalize_faces(img, faces_cord)
            vecs.append(model.get_vector(faces[0]))
    with open("people/database.pkl", 'rb') as data:
        database = pickle.load(data)
    database[1] += vecs
    for i in range(len(vecs)):
        database[0][len(database[0])] = name
        print("added name " + name + 'at' + str(len(database[1])))
    with open("people/database.pkl", 'wb') as data:
        pickle.dump(database, data)
        print("data dumped"+name)
    return database


def convert_to_vectors(users, model):
    db = firebase.database()
    storage = firebase.storage()
    for key in users.val():
        os.mkdir('new_images/' + key)
        for i in range(10):
            storage.child("customers/profile_pictures/"+key+"/"+str(i)+".jpeg").download('new_images/' + key + '/' + str(i)+".jpeg")

        database = upload_image(model, key)
        shutil.rmtree('new_images/' + key)
        db.child("new_users").child(key).remove()
    storage.child("database_backup/database.pkl").put('people/database.pkl')
    return database
# Out:
# Using TensorFlow backend.

# %%
class VideoCamera(object):
    def __init__(self, index=0):
        self.video = cv2.VideoCapture(index)
        self.index = index
        print(self.video.isOpened())

    def __del__(self):
        self.video.release()

    def get_frame(self, in_grayscale=False):
        _, frame = self.video.read()
        original_frame = frame
        if in_grayscale:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        return original_frame, frame


def cut_faces(image, face_cord):
    faces = []
    for x, y, w, h in face_cord:
       # w_temp = int(0.2 * w/2)
        faces.append(image[y:y+h, x:x+w, :])
    return faces


def resize(images, size=(96, 96)):
    images_norm = []
    for image in images:
        if image.shape < size:
            image_norm = cv2.resize(image, size, interpolation=cv2.INTER_AREA)
        else:
            image_norm = cv2.resize(image, size, interpolation=cv2.INTER_CUBIC)
        images_norm.append(image_norm)
    return images_norm

def draw_rectangles(image, cords):
    for x, y, w, h in cords:
        w_temp = int(0.2 * w/2)
        cv2.rectangle(image, (x+w_temp, y),(x+w-w_temp, y+h), (150,150,0), 8)


def preprocessed_faces(frame, faces_cord, size=(96, 96)):
    faces = cut_faces(frame, faces_cord)
    faces = resize(faces,size)
    return faces


def normalize_faces(frame, faces_cord, size=(96, 96)):
    faces = cut_faces(frame, faces_cord)
    faces = resize(faces,size)
    return faces

# %%
class FaceDetector(object):
    def __init__(self):
        self.classifier = cv2.CascadeClassifier('opencv_dependency/haarcascade_frontalface_default.xml')

    def detect(self, image, biggest_only=True):
        scale_factor = 1.2
        min_neighbours = 5
        min_size = (30, 30)
        biggest_only = True
        flags = cv2.CASCADE_FIND_BIGGEST_OBJECT | \
                cv2.CASCADE_DO_ROUGH_SEARCH if biggest_only else \
            cv2.CASCADE_SCALE_IMAGE
        faces_cord = self.classifier.detectMultiScale(image, scaleFactor=scale_factor, minNeighbors=min_neighbours,
                                                      minSize=min_size, flags=flags)
        return faces_cord
camera = VideoCamera()
image, _ = camera.get_frame()
detector = FaceDetector()
faces = detector.detect(image)
del camera
faces
# Out:
# True
# array([[245, 148, 246, 246]], dtype=int32)

# %%
camera = VideoCamera()
camera.get_frame()
del camera
# Out:
# True

# %%
faces = normalize_faces(image, faces)

# %%
faces
# Out:
# [array([[[152, 152, 151],
#          [148, 151, 151],
#          [ 98, 100, 100],
#          ...,
#          [126, 128, 128],
#          [134, 136, 135],
#          [129, 133, 132]],
#
#         [[150, 150, 150],
#          [129, 128, 128],
#          [100, 103, 103],
#          ...,
#          [128, 131, 127],
#          [133, 139, 135],
#          [123, 133, 133]],
#
#         [[149, 149, 148],
#          [105, 106, 102],
#          [102, 101, 102],
#          ...,
#          [122, 129, 128],
#          [128, 133, 131],
#          [131, 136, 133]],
#
#         ...,
#         [[255, 210, 119],
#          [255, 213, 123],
#          [255, 216, 124],
#          ...,
#          [255, 201, 105],
#          [255, 204, 112],
#          [255, 208, 118]],
#
#         [[255, 211, 120],
#          [255, 216, 123],
#          [255, 215, 124],
#          ...,
#          [255, 208, 110],
#          [255, 208, 118],
#          [255, 209, 122]],
#
#         [[255, 213, 120],
#          [255, 216, 121],
#          [255, 215, 120],
#          ...,
#          [255, 210, 114],
#          [255, 210, 120],
#          [255, 207, 113]]], dtype=uint8)]

# %%
from keras_model import *
model = FaceDetection()

# %%
a = model.get_vector(faces[0])

# %%
mind, identity = model.predict(faces[0])
print(str(mind))
identity
# Out:
# Not in the database.
# 0.647281
# 'unknown'

# %%
model.dumpData()

# %%
def check_for_new():
    try:
        db = firebase.database()
        users = db.child("new_users").shallow().get()
        if users.val() is None:
            print("here")
            return False, None
        print("there")
        return bool(users), users
    except:
        return False, None
u, users = check_for_new()
print(str(u) +'\n' + str(users))
# Out:
# there
# True
# <pyrebase.pyrebase.PyreResponse object at 0x000001C1F97F4EB8>

# %%
def add_to_firebase(identity, timestamp, face):
    db = firebase.database()
    storage = firebase.storage()
    current_pending_requests = db.child("notifications").shallow().get()
    if identity not in current_pending_requests.val():
        cv2.imwrite('notification_images/' + identity + '.jpeg', face)
        data = {'timestamp': timestamp}
        db.child("notifications").child(identity).set(data)
        storage.child("notifications/"+identity+".jpeg").put('notification_images/' + identity + '.jpeg')
        os.remove('notification_images/' + identity + '.jpeg')
        
add_to_firebase('raj','2018-03-18 17:20:15', faces[0])

# %%
import pyrebase

def get_pickle_from_firebase():
    storage = firebase.storage()
    storage.child("database_backup/database.pkl").download('people/database.pkl')
get_pickle_from_firebase()

# %%
def upload_image(model, key):
    detector = FaceDetector()
    name = key
    images = [image for image in os.listdir('new_images/'+key)]
    vecs = []
    database = None
    for image in images:
        img = cv2.imread('new_images/' + key + '/' + image, 1)
        faces_cord = detector.detect(img)
        print("image aaya")
        if len(faces_cord):
            print("face aaya")
            faces = normalize_faces(img, faces_cord)
            vecs.append(model.get_vector(faces[0]))
    with open("people/database.pkl", 'rb') as data:
        database = pickle.load(data)
    database[1] += vecs
    for i in range(len(vecs)):
        database[0][len(database[0])] = name
        print("added name " + name + 'at' + str(len(database[1])))
    with open("people/database.pkl", 'wb') as data:
        pickle.dump(database, data)
        print("data dumped"+name)
    return database


def convert_to_vectors(users, model):
    db = firebase.database()
    storage = firebase.storage()
    for key in users.val():
        os.mkdir('new_images/' + key)
        for i in range(10):
            storage.child("customers/profile_pictures/"+key+"/"+str(i)+".jpeg").download('new_images/' + key + '/' + str(i)+".jpeg")

        database = upload_image(model, key)
        shutil.rmtree('new_images/' + key)
        db.child("new_users").child(key).remove()
    storage.child("database_backup/database.pkl").put('people/database.pkl')
    return database

# %%
database = convert_to_vectors(users, model)
print(str(database))
# Out:
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# image aaya
# face aaya
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# added name rajat20
# data dumpedraj
# [{0: '-L7oIL5gIS7PTcziEjpA', 1: '-L7oIL5gIS7PTcziEjpA', 2: '-L7oIL5gIS7PTcziEjpA', 3: '-L7oIL5gIS7PTcziEjpA', 4: '-L7oIL5gIS7PTcziEjpA', 5: '-L7oIL5gIS7PTcziEjpA', 6: '-L7oIL5gIS7PTcziEjpA', 7: '-L7oIL5gIS7PTcziEjpA', 8: '-L7oIL5gIS7PTcziEjpA', 9: '-L7oIL5gIS7PTcziEjpA', 10: 'raj', 11: 'raj', 12: 'raj', 13: 'raj', 14: 'raj', 15: 'raj', 16: 'raj', 17: 'raj', 18: 'raj', 19: 'raj'}, [array([[  1.11603417e-01,   3.97236273e-02,  -9.49358568e-02,
#          -4.01375786e-04,   5.99205717e-02,   1.97685912e-01,
#           9.31200758e-02,   1.48292566e-02,   5.58602391e-03,
#          -1.88426375e-01,   5.65971360e-02,   1.08712673e-01,
#           6.18267804e-02,  -1.31425247e-01,  -1.13892570e-01,
